# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import pandas as pd
Food = pd.read_csv(r'C:\Users\Mubashar Hanif\Downloads\agri data\Datafiniti_Fast_Food_Restaurants.csv')
print(Food)
# Out:
#       index                    id             dateAdded           dateUpdated  \
# 0         0  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 1         1  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 2         2  AVwcopQoByjofQCxgfVa  2016-03-29T05:06:36Z  2018-06-26T02:59:52Z
# 3         3  AVweXN5RByjofQCxxilK  2017-01-03T07:46:11Z  2018-06-26T02:59:51Z
# 4         4  AWQ6MUvo3-Khe5l_j3SG  2018-06-26T02:59:43Z  2018-06-26T02:59:43Z
# ...     ...                   ...                   ...                   ...
# 9995   9995  AV12gJwna4HuVbed9Ayg  2017-07-24T21:28:46Z  2018-04-07T13:19:06Z
# 9996   9996  AV12gJxKIxWefVJwhpzS  2017-07-24T21:28:46Z  2018-04-07T13:19:05Z
# 9997   9997  AVwdJMdSByjofQCxl8Vr  2015-10-24T00:17:32Z  2018-04-07T13:19:05Z
# 9998   9998  AVwdl2cykufWRAb57ZPs  2016-04-05T02:59:45Z  2018-04-07T13:19:05Z
# 9999   9999  AVwdecWKIN2L1WUfwMWU  2016-11-08T02:26:32Z  2018-04-07T13:19:05Z
#
# ...

# %%
# count the rows and columns in a DataFrame
print("Number of rows and column in our Food = ", Food .shape)
# Out:
# Number of rows and column in our Food =  (10000, 16)

# %%
print("Data types:")
print(Food.dtypes)
# Out:
# Data types:
# index            int64
# id              object
# dateAdded       object
# dateUpdated     object
# address         object
# categories      object
# city            object
# country         object
# keys            object
# latitude       float64
# longitude      float64
# name            object
# postalCode      object
# province        object
# sourceURLs      object
# websites        object
# dtype: object

# %%
# Checks for null Values, Returns Boolean Array
Food . isnull()
# Out:
#       index     id  dateAdded  dateUpdated  address  categories   city  \
# 0     False  False      False        False    False       False  False
# 1     False  False      False        False    False       False  False
# 2     False  False      False        False    False       False  False
# 3     False  False      False        False    False       False  False
# 4     False  False      False        False    False       False  False
# ...     ...    ...        ...          ...      ...         ...    ...
# 9995  False  False      False        False    False       False  False
# 9996  False  False      False        False    False       False  False
# 9997  False  False      False        False    False       False  False
# 9998  False  False      False        False    False       False  False
# 9999  False  False      False        False    False       False  False
#
#       country   keys  latitude  longitude   name  postalCode  province  \
# ...

# %%
# Opposite of s.isnull()
Food . notnull()
# Out:
#       index    id  dateAdded  dateUpdated  address  categories  city  country  \
# 0      True  True       True         True     True        True  True     True
# 1      True  True       True         True     True        True  True     True
# 2      True  True       True         True     True        True  True     True
# 3      True  True       True         True     True        True  True     True
# 4      True  True       True         True     True        True  True     True
# ...     ...   ...        ...          ...      ...         ...   ...      ...
# 9995   True  True       True         True     True        True  True     True
# 9996   True  True       True         True     True        True  True     True
# 9997   True  True       True         True     True        True  True     True
# 9998   True  True       True         True     True        True  True     True
# 9999   True  True       True         True     True        True  True     True
#
# ...

# %%
# Drops all rows that contain null values
Food . dropna()
# Out:
#       index                    id             dateAdded           dateUpdated  \
# 0         0  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 1         1  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 2         2  AVwcopQoByjofQCxgfVa  2016-03-29T05:06:36Z  2018-06-26T02:59:52Z
# 3         3  AVweXN5RByjofQCxxilK  2017-01-03T07:46:11Z  2018-06-26T02:59:51Z
# 4         4  AWQ6MUvo3-Khe5l_j3SG  2018-06-26T02:59:43Z  2018-06-26T02:59:43Z
# ...     ...                   ...                   ...                   ...
# 9995   9995  AV12gJwna4HuVbed9Ayg  2017-07-24T21:28:46Z  2018-04-07T13:19:06Z
# 9996   9996  AV12gJxKIxWefVJwhpzS  2017-07-24T21:28:46Z  2018-04-07T13:19:05Z
# 9997   9997  AVwdJMdSByjofQCxl8Vr  2015-10-24T00:17:32Z  2018-04-07T13:19:05Z
# 9998   9998  AVwdl2cykufWRAb57ZPs  2016-04-05T02:59:45Z  2018-04-07T13:19:05Z
# 9999   9999  AVwdecWKIN2L1WUfwMWU  2016-11-08T02:26:32Z  2018-04-07T13:19:05Z
#
# ...

# %%
#Prints number of rows and columns in dataframe
Food.head()
# Out:
#    index                    id             dateAdded           dateUpdated  \
# 0      0  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 1      1  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 2      2  AVwcopQoByjofQCxgfVa  2016-03-29T05:06:36Z  2018-06-26T02:59:52Z
# 3      3  AVweXN5RByjofQCxxilK  2017-01-03T07:46:11Z  2018-06-26T02:59:51Z
# 4      4  AWQ6MUvo3-Khe5l_j3SG  2018-06-26T02:59:43Z  2018-06-26T02:59:43Z
#
#                 address                                    categories  \
# 0      800 N Canal Blvd  American Restaurant and Fast Food Restaurant
# 1      800 N Canal Blvd                         Fast Food Restaurants
# 2   206 Wears Valley Rd                          Fast Food Restaurant
# 3          3652 Parkway                                     Fast Food
# 4  2118 Mt Zion Parkway                          Fast Food Restaurant
#
#            city country                                           keys  \
# ...

# %%
# Prints last n rows of the DataFrame
Food . tail()
# Out:
#       index                    id             dateAdded           dateUpdated  \
# 9995   9995  AV12gJwna4HuVbed9Ayg  2017-07-24T21:28:46Z  2018-04-07T13:19:06Z
# 9996   9996  AV12gJxKIxWefVJwhpzS  2017-07-24T21:28:46Z  2018-04-07T13:19:05Z
# 9997   9997  AVwdJMdSByjofQCxl8Vr  2015-10-24T00:17:32Z  2018-04-07T13:19:05Z
# 9998   9998  AVwdl2cykufWRAb57ZPs  2016-04-05T02:59:45Z  2018-04-07T13:19:05Z
# 9999   9999  AVwdecWKIN2L1WUfwMWU  2016-11-08T02:26:32Z  2018-04-07T13:19:05Z
#
#                    address             categories           city country  \
# 9995     3460 Robinhood Rd  Fast Food Restaurants  Winston-Salem      US
# 9996  3069 Kernersville Rd  Fast Food Restaurants  Winston-Salem      US
# 9997         838 S Main St  Fast Food Restaurants   Kernersville      US
# 9998   1702 Glendale Dr SW  Fast Food Restaurants         Wilson      US
# 9999       1405 W Broad St  Fast Food Restaurants  Elizabethtown      US
#
# ...

# %%
# the id, keys, sourceURLs, and websites are unique identifier
# we don't need them in our visualizations
Food = Food.drop(['id', 'keys', 'sourceURLs', 'websites'], axis=1)

# shape of dataset
print("Dimension after dropping columns:")
print(Food.shape)

# take a peek at the head to verify the drop is successful
Food.head()
# Out:
# Dimension after dropping columns:
# (10000, 12)
#    index             dateAdded           dateUpdated               address  \
# 0      0  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z      800 N Canal Blvd
# 1      1  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z      800 N Canal Blvd
# 2      2  2016-03-29T05:06:36Z  2018-06-26T02:59:52Z   206 Wears Valley Rd
# 3      3  2017-01-03T07:46:11Z  2018-06-26T02:59:51Z          3652 Parkway
# 4      4  2018-06-26T02:59:43Z  2018-06-26T02:59:43Z  2118 Mt Zion Parkway
#
#                                      categories          city country  \
# 0  American Restaurant and Fast Food Restaurant     Thibodaux      US
# 1                         Fast Food Restaurants     Thibodaux      US
# 2                          Fast Food Restaurant  Pigeon Forge      US
# 3                                     Fast Food  Pigeon Forge      US
# 4                          Fast Food Restaurant        Morrow      US
#
# ...

# %%
import matplotlib.pyplot as plt # import matplotlib for graphs

# %%
print("Count of unique value 1", Food['name'].nunique())

print("Count of unique  value 2", Food['address'].nunique())

print("Count of unique  value 3", Food['city'].nunique())

print("Count of unique  value 4", Food['postalCode'].nunique())
# Out:
# Count of unique value 1 571
# Count of unique  value 2 9302
# Count of unique  value 3 2764
# Count of unique  value 4 5429

# %%
# top 20 restaurants recorded by count total
nameplot=Food['name'].value_counts()[:20].plot.bar(title='Top 10 mentioned restaurants')
nameplot.set_xlabel('name',size=10)
nameplot.set_ylabel('count',size=10)
# Out:
# Text(0, 0.5, 'count')

# %%
# take a peek at the dateAdded column
Food['dateAdded'].head()
# Out:
# 0    2015-10-19T23:47:58Z
# 1    2015-10-19T23:47:58Z
# 2    2016-03-29T05:06:36Z
# 3    2017-01-03T07:46:11Z
# 4    2018-06-26T02:59:43Z
# Name: dateAdded, dtype: object

# %%
# let's parse the dates for dateAdded and dateUpdated
from datetime import datetime
from dateutil.parser import parse

# %%
# let's convert dateAdded and dateUpdated column data to 
# datetime object with apply function
Food['dateAdded'] = Food['dateAdded'].apply(
        lambda x: datetime.strptime(x, '%Y-%m-%dT%H:%M:%SZ'))
Food['dateUpdated'] = Food['dateUpdated'].apply(
        lambda x: datetime.strptime(x, '%Y-%m-%dT%H:%M:%SZ'))

# %%
# To check if our conversion worked 
Food['dateAdded'].head()
# Out:
# 0   2015-10-19 23:47:58
# 1   2015-10-19 23:47:58
# 2   2016-03-29 05:06:36
# 3   2017-01-03 07:46:11
# 4   2018-06-26 02:59:43
# Name: dateAdded, dtype: datetime64[ns]

# %%
Food['dateUpdated'].head()
# Out:
# 0   2018-06-26 03:00:14
# 1   2018-06-26 03:00:14
# 2   2018-06-26 02:59:52
# 3   2018-06-26 02:59:51
# 4   2018-06-26 02:59:43
# Name: dateUpdated, dtype: datetime64[ns]

# %%
pip install -U pandas-profiling[notebook,unicode]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall pandas_profiling
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
Food.describe(include='all')
# Out:
# C:\Users\Mubashar Hanif\AppData\Local\Temp\ipykernel_13952\2550735278.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   Food.describe(include='all')
# C:\Users\Mubashar Hanif\AppData\Local\Temp\ipykernel_13952\2550735278.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   Food.describe(include='all')
#               index            dateAdded          dateUpdated  \
# count   10000.00000                10000                10000
# unique          NaN                 8960                 7052
# top             NaN  2017-06-19 14:48:37  2018-06-19 09:42:27
# ...

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(Food)
profile
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:03<00:00,  3.68s/it]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.4.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-11-18 16:56:18.778570&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file("Analysis.json")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 14.08it/s]

# %%
profile.to_file("Analysis.html")
# Out:
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 62.50it/s]

# %%
nameplot=Food['city'].value_counts()[:10].plot.bar(title='City with most number of restaurants')
nameplot.set_xlabel('city',size=10)
nameplot.set_ylabel('count',size=10)
# Out:
# Text(0, 0.5, 'count')
